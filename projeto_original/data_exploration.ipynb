# %% [markdown]
# ### Carregamento dos Dados

# %%
import pandas as pd

df = pd.read_csv('../data/creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.shape
# Out:
# (284807, 31)

# %% [markdown]
# ### Exploração dos Dados

# %%
# Filtragem de nulos no dataframe

df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# O resultado nos diz que não há nulos...

# %%
# Filtragem de duplicados no dataframe

df[df.duplicated()].shape
# Out:
# (1081, 31)

# %%
df[df.duplicated()][df['Class'] == 1].shape
# Out:
# /tmp/ipykernel_7025/3819310256.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df.duplicated()][df['Class'] == 1].shape
# (19, 31)

# %% [markdown]
# Temos 1081 transações duplicadas, sendo que 19 delas são da classe minoritária (fraudulenta). Vamos eliminá-las...

# %%
df = df.drop_duplicates()

df[df.duplicated()].shape
# Out:
# (0, 31)

# %% [markdown]
# ### Transformação dos Dados e SMOTE
#
# Antes de aplicarmos o K-means, precisamos transformar nossos dados para um formato que melhor se adeque ao modelo. Em adicão a isso, aplicamos o SMOTE para que possamos compensar a classe minoritária.

# %%
from imblearn.over_sampling import SMOTE

# %% [markdown]
# dividimos os dados

# %%
X = df.drop('Class', axis=1) 
y = df['Class']

# %% [markdown]
# Aplicamos o SMOTE

# %%
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# %%
df_resampled = pd.DataFrame(X_resampled, columns=X.columns)
df_resampled['Class'] = y_resampled

# %% [markdown]
# Juntamos os dados para um csv maior
#
# Vamos fazer um standardization também, para o valores poderem ser usados pelo modelos

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_resampled["Amount"] =  scaler.fit_transform(df_resampled["Amount"].values.reshape(-1,1))

# %% [markdown]
# Visualizacao dos dados tratados

# %%
df_resampled
# Out:
#                  Time        V1        V2         V3        V4        V5  \
# 0            0.000000 -1.359807 -0.072781   2.536347  1.378155 -0.338321
# 1            0.000000  1.191857  0.266151   0.166480  0.448154  0.060018
# 2            1.000000 -1.358354 -1.340163   1.773209  0.379780 -0.503198
# 3            1.000000 -0.966272 -0.185226   1.792993 -0.863291 -0.010309
# 4            2.000000 -1.158233  0.877737   1.548718  0.403034 -0.407193
# ...               ...       ...       ...        ...       ...       ...
# 566501   41183.445750 -7.151786  5.337862 -10.524210  6.638176 -7.107253
# 566502   14264.057012 -4.705909  8.250299 -14.559164  9.787990 -4.117161
# 566503  135064.971368  0.407366  1.352354  -4.892782  3.554728 -1.282114
# 566504  109361.849259  0.580032  2.773047  -5.790024  5.606953  0.398480
# 566505   84438.552579 -2.819178  2.410529  -5.833727  4.099991 -2.622497
#
#               V6         V7        V8        V9  ...       V21       V22  \
# 0       0.462388   0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361  -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499   0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203   0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921   0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...        ...       ...       ...  ...       ...       ...
# 566501 -3.688276 -11.629728  4.641323 -6.040679  ...  2.101089 -0.223411
# 566502 -3.169121 -10.169571  4.500750 -5.177936  ...  1.988732  0.194092
# 566503 -1.271505  -0.977517  0.462476 -1.442286  ...  0.765180  0.703300
# 566504 -0.621865  -2.954884  0.837074 -1.822486  ...  0.311488 -0.810361
# 566505 -2.198030  -6.054611  1.857574 -3.791847  ...  1.163557 -0.244352
#
#              V23       V24       V25       V26       V27       V28    Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  0.238968
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724 -0.424565
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  1.273308
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  0.121010
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153 -0.120640
# ...          ...       ...       ...       ...       ...       ...       ...
# 566501  0.029599  0.393875 -0.049155  0.544700  1.306198  0.223600 -0.357981
# 566502  0.480124 -1.079562 -0.444215  0.557467  1.234855  0.627900 -0.429040
# 566503  0.814076  0.814930 -0.300969  0.168339  0.236775  0.037244  0.841150
# 566504 -0.067584 -0.632356  0.414552  0.073243  0.736440  0.358067 -0.417994
# 566505  0.134456 -0.292208  0.685146  0.740121  1.406461  0.319263 -0.410103
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 566501      1
# 566502      1
# 566503      1
# 566504      1
# 566505      1
#
# [566506 rows x 31 columns]

# %% [markdown]
# Exportamos os dados para um csv, para uso posteriori

# %%
#df_resampled.to_csv("../data/creditcard_treated.csv")
